# %%
import tensorflow as tf
tf.keras.backend.clear_session()
from EQTransformer.core.trainer import trainer

trainer(input_hdf5='ModelsAndSampleData/100samples.hdf5',
        input_csv='ModelsAndSampleData/100samples.csv',
        output_name='test_samples',
        cnn_blocks=2,
        lstm_blocks=1,
        padding='same',
        activation='relu',
        drop_rate=0.2,
        label_type='gaussian',
        add_event_r=0.6,
        add_gap_r=0.2,
        shift_event_r=0.9,
        add_noise_r=0.5,
        mode='generator',
        train_valid_test_split=[0.60, 0.20, 0.20],
        batch_size=20,
        epochs=10,
        patience=2,
        gpuid=None,
        gpu_limit=None)
# Out:
# Learning rate:  0.001
# Optimizer adam
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 6000, 3)]    0
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 6000, 8)      272         input[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_7 (MaxPooling1D)  (None, 3000, 8)      0           conv1d_28[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 3000, 16)     1168        max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_8 (MaxPooling1D)  (None, 1500, 16)     0           conv1d_29[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 1500, 16)     1808        max_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_9 (MaxPooling1D)  (None, 750, 16)      0           conv1d_30[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 750, 32)      3616        max_pooling1d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_10 (MaxPooling1D) (None, 375, 32)      0           conv1d_31[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 375, 32)      5152        max_pooling1d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_11 (MaxPooling1D) (None, 188, 32)      0           conv1d_32[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 188, 64)      10304       max_pooling1d_11[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_12 (MaxPooling1D) (None, 94, 64)       0           conv1d_33[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 94, 64)       12352       max_pooling1d_12[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_13 (MaxPooling1D) (None, 47, 64)       0           conv1d_34[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_21 (UpSampling1D) (None, 94, 64)       0           max_pooling1d_13[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_28 (UpSampling1D) (None, 94, 64)       0           max_pooling1d_13[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_35 (UpSampling1D) (None, 94, 64)       0           max_pooling1d_13[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 94, 64)       12352       up_sampling1d_21[0][0]
# __________________________________________________________________________________________________
# conv1d_42 (Conv1D)              (None, 94, 64)       12352       up_sampling1d_28[0][0]
# __________________________________________________________________________________________________
# conv1d_49 (Conv1D)              (None, 94, 64)       12352       up_sampling1d_35[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_22 (UpSampling1D) (None, 188, 64)      0           conv1d_35[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_29 (UpSampling1D) (None, 188, 64)      0           conv1d_42[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_36 (UpSampling1D) (None, 188, 64)      0           conv1d_49[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 188, 64)      20544       up_sampling1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_43 (Conv1D)              (None, 188, 64)      20544       up_sampling1d_29[0][0]
# __________________________________________________________________________________________________
# conv1d_50 (Conv1D)              (None, 188, 64)      20544       up_sampling1d_36[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_23 (UpSampling1D) (None, 376, 64)      0           conv1d_36[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_30 (UpSampling1D) (None, 376, 64)      0           conv1d_43[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_37 (UpSampling1D) (None, 376, 64)      0           conv1d_50[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 376, 32)      10272       up_sampling1d_23[0][0]
# __________________________________________________________________________________________________
# conv1d_44 (Conv1D)              (None, 376, 32)      10272       up_sampling1d_30[0][0]
# __________________________________________________________________________________________________
# conv1d_51 (Conv1D)              (None, 376, 32)      10272       up_sampling1d_37[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_24 (UpSampling1D) (None, 752, 32)      0           conv1d_37[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_31 (UpSampling1D) (None, 752, 32)      0           conv1d_44[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_38 (UpSampling1D) (None, 752, 32)      0           conv1d_51[0][0]
# __________________________________________________________________________________________________
# cropping1d_3 (Cropping1D)       (None, 750, 32)      0           up_sampling1d_24[0][0]
# __________________________________________________________________________________________________
# cropping1d_4 (Cropping1D)       (None, 750, 32)      0           up_sampling1d_31[0][0]
# __________________________________________________________________________________________________
# cropping1d_5 (Cropping1D)       (None, 750, 32)      0           up_sampling1d_38[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 750, 32)      7200        cropping1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_45 (Conv1D)              (None, 750, 32)      7200        cropping1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_52 (Conv1D)              (None, 750, 32)      7200        cropping1d_5[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_25 (UpSampling1D) (None, 1500, 32)     0           conv1d_38[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_32 (UpSampling1D) (None, 1500, 32)     0           conv1d_45[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_39 (UpSampling1D) (None, 1500, 32)     0           conv1d_52[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 1500, 16)     3600        up_sampling1d_25[0][0]
# __________________________________________________________________________________________________
# conv1d_46 (Conv1D)              (None, 1500, 16)     3600        up_sampling1d_32[0][0]
# __________________________________________________________________________________________________
# conv1d_53 (Conv1D)              (None, 1500, 16)     3600        up_sampling1d_39[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_26 (UpSampling1D) (None, 3000, 16)     0           conv1d_39[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_33 (UpSampling1D) (None, 3000, 16)     0           conv1d_46[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_40 (UpSampling1D) (None, 3000, 16)     0           conv1d_53[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 3000, 16)     2320        up_sampling1d_26[0][0]
# __________________________________________________________________________________________________
# conv1d_47 (Conv1D)              (None, 3000, 16)     2320        up_sampling1d_33[0][0]
# __________________________________________________________________________________________________
# conv1d_54 (Conv1D)              (None, 3000, 16)     2320        up_sampling1d_40[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_27 (UpSampling1D) (None, 6000, 16)     0           conv1d_40[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_34 (UpSampling1D) (None, 6000, 16)     0           conv1d_47[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_41 (UpSampling1D) (None, 6000, 16)     0           conv1d_54[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 6000, 8)      1416        up_sampling1d_27[0][0]
# __________________________________________________________________________________________________
# conv1d_48 (Conv1D)              (None, 6000, 8)      1416        up_sampling1d_34[0][0]
# __________________________________________________________________________________________________
# conv1d_55 (Conv1D)              (None, 6000, 8)      1416        up_sampling1d_41[0][0]
# __________________________________________________________________________________________________
# detector (Conv1D)               (None, 6000, 1)      89          conv1d_41[0][0]
# __________________________________________________________________________________________________
# picker_P (Conv1D)               (None, 6000, 1)      89          conv1d_48[0][0]
# __________________________________________________________________________________________________
# picker_S (Conv1D)               (None, 6000, 1)      89          conv1d_55[0][0]
# ==================================================================================================
# Total params: 208,051
# Trainable params: 208,051
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 60
# Started training in generator mode ...
# Learning rate:  0.001
# Epoch 1/10
# 1/6 [====>.........................] - ETA: 58s - loss: 0.6980 - detector_loss: 0.6923 - picker_P_loss: 0.6946 - picker_S_loss: 0.6994 - detector_f1: 0.0000e+00 - detector_accuracy: 0.7664 - picker_P_f1: 4.8646e-04 - picker_P_accuracy: 0.0451 - picker_S_f1: 0.0018 - picker_S_accuracy: 0.0067
# Process Keras_worker_ForkPoolWorker-37:
# Process Keras_worker_ForkPoolWorker-40:
# Process Keras_worker_ForkPoolWorker-36:
# Process Keras_worker_ForkPoolWorker-46:
# Process Keras_worker_ForkPoolWorker-38:
# Process Keras_worker_ForkPoolWorker-39:
# Process Keras_worker_ForkPoolWorker-48:
# Process Keras_worker_ForkPoolWorker-34:
# Process Keras_worker_ForkPoolWorker-45:
# Process Keras_worker_ForkPoolWorker-43:
# Process Keras_worker_ForkPoolWorker-44:
# Process Keras_worker_ForkPoolWorker-35:
# Process Keras_worker_ForkPoolWorker-47:
# Process Keras_worker_ForkPoolWorker-41:
# Process Keras_worker_ForkPoolWorker-42:
# Process Keras_worker_ForkPoolWorker-33:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/opt/anaconda3/envs/wave/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     600   if all(isinstance(g, ops.Tensor) for g in gradients):
# --> 601     return gen_math_ops.add_n(gradients)
#     602   else:
#
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/ops/gen_math_ops.py in add_n(inputs, name)
#     455         _ctx._context_handle, _ctx._thread_local_data.device_name, "AddN",
# --> 456         name, _ctx._post_execution_callbacks, inputs)
#     457       return _result
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# ...
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#
# SystemError: <built-in function len> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /var/folders/bf/38wkblrs3177r6h13m5t71_h0000gn/T/ipykernel_10055/1047957085.py in <module>
#      20         patience=2,
#      21         gpuid=None,
# ---> 22         gpu_limit=None)
#
# ~/Documents/GitHub/wave/final/EQTransformer/core/trainer.py in trainer(input_hdf5, input_csv, output_name, input_dimention, cnn_blocks, lstm_blocks, padding, activation, drop_rate, shuffle, label_type, normalization_mode, augmentation, add_event_r, shift_event_r, add_noise_r, drop_channel_r, add_gap_r, coda_ratio, scale_amplitude_r, pre_emphasis, loss_weights, loss_types, train_valid_test_split, mode, batch_size, epochs, monitor, patience, gpuid, gpu_limit, use_multiprocessing)
#     350         return history, model, start_training, end_training, save_dir, save_models, len(training), len(validation)
#     351
# --> 352     history, model, start_training, end_training, save_dir, save_models, training_size, validation_size=train(args)
#     353     _document_training(history, model, start_training, end_training, save_dir, save_models, training_size, validation_size, args)
#     354
#
# ~/Documents/GitHub/wave/final/EQTransformer/core/trainer.py in train(args)
#     318                                           callbacks=callbacks,
#     319                                           epochs=args['epochs'],
# --> 320                                           class_weight=['detector', 'picker_P', 'picker_S'])
#     321
#     322         elif args['mode'] == 'preload':
#
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1295         shuffle=shuffle,
#    1296         initial_epoch=initial_epoch,
# -> 1297         steps_name='steps_per_epoch')
#    1298
#    1299   def evaluate_generator(self,
#
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     263
#     264       is_deferred = not model._is_compiled
# --> 265       batch_outs = batch_function(*batch_data)
#     266       if not isinstance(batch_outs, list):
#     267         batch_outs = [batch_outs]
#
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#     971       outputs = training_v2_utils.train_on_batch(
#     972           self, x, y=y, sample_weight=sample_weight,
# --> 973           class_weight=class_weight, reset_metrics=reset_metrics)
#     974       outputs = (outputs['total_loss'] + outputs['output_losses'] +
#     975                  outputs['metrics'])
#
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in train_on_batch(model, x, y, sample_weight, class_weight, reset_metrics)
#     262       y,
#     263       sample_weights=sample_weights,
# --> 264       output_loss_metrics=model._output_loss_metrics)
#     265
#     266   if reset_metrics:
#
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_eager.py in train_on_batch(model, inputs, targets, sample_weights, output_loss_metrics)
#     309           sample_weights=sample_weights,
#     310           training=True,
# --> 311           output_loss_metrics=output_loss_metrics))
#     312   if not isinstance(outs, list):
#     313     outs = [outs]
#
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_eager.py in _process_single_batch(model, inputs, targets, output_loss_metrics, sample_weights, training)
#     266           model._backwards(tape, scaled_total_loss)
#     267         else:
# --> 268           grads = tape.gradient(scaled_total_loss, trainable_weights)
#     269           if isinstance(model.optimizer,
#     270                         loss_scale_optimizer.LossScaleOptimizer):
#
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1012         output_gradients=output_gradients,
#    1013         sources_raw=flat_sources_raw,
# -> 1014         unconnected_gradients=unconnected_gradients)
#    1015
#    1016     if not self._persistent:
#
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/imperative_grad.py in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      74       output_gradients,
#      75       sources_raw,
# ---> 76       compat.as_str(unconnected_gradients.value))
#
# /opt/anaconda3/envs/wave/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _aggregate_grads(gradients)
#     596   assert gradients, "No gradients to aggregate"
#     597
# --> 598   if len(gradients) == 1:
#     599     return gradients[0]
#     600   if all(isinstance(g, ops.Tensor) for g in gradients):
#
# SystemError: <built-in function len> returned a result with an error set
